# %%
import os
train = ['https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/train.dat', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/train2.dat', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/train3.dat', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/train4.dat']
test =  ['https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/test.dat', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/test2.dat', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/test3.dat', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/test4.dat']
outputs = ['https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/tree.txt', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/tree2.txt', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/tree3.txt', 'https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/tree4.txt']
# Put train files in .train/
# !mkdir train 
for i in train:
    os.system('wget -P ./train ' + i + ' --no-check-certificate')
# Put test files in .test/
# !mkdir test 
for i in test:
    os.system('wget -P ./test ' + i + ' --no-check-certificate')
# Put output files in ./output
# !mkdir output
for i in outputs:
    os.system('wget -P ./output ' + i + ' --no-check-certificate')
# Out:
# 363.56s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# --2023-09-05 16:00:36--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/train.dat
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 11246 (11K)
# Saving to: ‘./train/train.dat’
#
#      0K ..........                                            100% 9.45M=0.001s
#
# 2023-09-05 16:00:36 (9.45 MB/s) - ‘./train/train.dat’ saved [11246/11246]
#
# --2023-09-05 16:00:36--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/train2.dat
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 10445 (10K)
# Saving to: ‘./train/train2.dat’
#
#      0K ..........                                            100% 5.35M=0.002s
#
# 2023-09-05 16:00:36 (5.35 MB/s) - ‘./train/train2.dat’ saved [10445/10445]
#
# --2023-09-05 16:00:36--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/train3.dat
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 10445 (10K)
# Saving to: ‘./train/train3.dat’
#
#      0K ..........                                            100% 6.30M=0.002s
#
# 2023-09-05 16:00:36 (6.30 MB/s) - ‘./train/train3.dat’ saved [10445/10445]
#
# --2023-09-05 16:00:36--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/train4.dat
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 11246 (11K)
# Saving to: ‘./train/train4.dat’
#
#      0K ..........                                            100% 1.32M=0.008s
#
# 2023-09-05 16:00:36 (1.32 MB/s) - ‘./train/train4.dat’ saved [11246/11246]
#
# 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 11246 (11K)
# Saving to: ‘./train/train4.dat’
#
#      0K ..........                                            100% 1.32M=0.008s
#
# 2023-09-05 16:00:36 (1.32 MB/s) - ‘./train/train4.dat’ saved [11246/11246]
#
# 369.02s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# --2023-09-05 16:00:41--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/test.dat
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 2888 (2.8K)
# Saving to: ‘./test/test.dat’
#
#      0K ..                                                    100% 52.0M=0s
#
# 2023-09-05 16:00:41 (52.0 MB/s) - ‘./test/test.dat’ saved [2888/2888]
#
# --2023-09-05 16:00:41--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/test2.dat
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 2645 (2.6K)
# Saving to: ‘./test/test2.dat’
#
#      0K ..                                                    100% 46.7M=0s
#
# 2023-09-05 16:00:41 (46.7 MB/s) - ‘./test/test2.dat’ saved [2645/2645]
#
# --2023-09-05 16:00:41--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/test3.dat
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 2645 (2.6K)
# Saving to: ‘./test/test3.dat’
#
#      0K ..                                                    100% 42.0M=0s
#
# 2023-09-05 16:00:41 (42.0 MB/s) - ‘./test/test3.dat’ saved [2645/2645]
#
# --2023-09-05 16:00:41--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/test4.dat
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 2888 (2.8K)
# Saving to: ‘./test/test4.dat’
#
#      0K ..                                                    100%  138M=0s
#
# 2023-09-05 16:00:41 (138 MB/s) - ‘./test/test4.dat’ saved [2888/2888]
#
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 2888 (2.8K)
# Saving to: ‘./test/test4.dat’
#
#      0K ..                                                    100%  138M=0s
#
# 2023-09-05 16:00:41 (138 MB/s) - ‘./test/test4.dat’ saved [2888/2888]
#
# 374.45s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# mkdir: output: File exists
# --2023-09-05 16:00:47--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/tree.txt
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 4165 (4.1K) [text/plain]
# Saving to: ‘./output/tree.txt.1’
#
#      0K ....                                                  100% 79.4M=0s
#
# 2023-09-05 16:00:47 (79.4 MB/s) - ‘./output/tree.txt.1’ saved [4165/4165]
#
# --2023-09-05 16:00:47--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/tree2.txt
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 7653 (7.5K) [text/plain]
# Saving to: ‘./output/tree2.txt.1’
#
#      0K .......                                               100% 6.11M=0.001s
#
# 2023-09-05 16:00:47 (6.11 MB/s) - ‘./output/tree2.txt.1’ saved [7653/7653]
#
# --2023-09-05 16:00:47--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/tree3.txt
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 9057 (8.8K) [text/plain]
# Saving to: ‘./output/tree3.txt.1’
#
#      0K ........                                              100% 38.4M=0s
#
# 2023-09-05 16:00:47 (38.4 MB/s) - ‘./output/tree3.txt.1’ saved [9057/9057]
#
# --2023-09-05 16:00:47--  https://www.hlt.utdallas.edu/~vince/cs4375/assignments/hw1/tree4.txt
# Resolving www.hlt.utdallas.edu (www.hlt.utdallas.edu)... 129.110.131.21
# Connecting to www.hlt.utdallas.edu (www.hlt.utdallas.edu)|129.110.131.21|:443... connected.
# WARNING: cannot verify www.hlt.utdallas.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 19791 (19K) [text/plain]
# Saving to: ‘./output/tree4.txt.1’
#
#      0K .......... .........                                  100% 2.24M=0.008s
#
# 2023-09-05 16:00:47 (2.24 MB/s) - ‘./output/tree4.txt.1’ saved [19791/19791]
