# %%
import pandas as pd

checkpoint_file = 'checkpoints_eval/data20.csv'
checkpoint_df = pd.read_csv(checkpoint_file)

# %%
nona = checkpoint_df.dropna()
nona[nona['predicted_answer_eval'] != nona['expert_label']]
nona
# Out:
#     Unnamed: 0.1  index  Unnamed: 0  \
# 0              0      4           4
# 1              1     14          14
# 2              2     32          32
# 3              3     35          35
# 4              4     42          42
# 5              5     46          46
# 6              6     59          59
# 7              7     62          62
# 8              8     73          73
# 9              9     80          80
# 10            10     87          87
# 11            11     94          94
# 13            13     96          96
# 14            14     99          99
# 15            15    102         102
# 16            16    106         106
# 17            17    122         122
# 18            18    124         124
# 19            19    132         132
# 20            20    137         137
#
#                                                  text  \
# 0   when you're the only dog left at the dog shelt...
# 1   six kids, no husband, no job, and food stamps ...
# 2        the face you make when your pussy gets hard.
# 3   if this is what they call pride.. then i don't...
# 4   behind this smile is an evil man known as hitler.
# 5                           when instincts take over.
# 6                            party tonight? i'm down.
# 7   this has nothing to do with this post but i ha...
# 8              sign says "take a quarter"  takes two.
# 9   when you are hanging out with your black frien...
# 10  when your ex says "you won't find a b*tch half...
# 11  the media calls them refugees but this is what...
# 13  transrepublican identifies as a republican, bu...
# 14          siri take me home starting route to jail.
# 15  stupid americans.. they elect their enemy to r...
# 16          who said i'm uneducated i have my master.
# 17   blacks are musical they always love a good beat.
# 18  yo dawg i heard you liked chinese food so we k...
# 19                                      '' shoot them
# 20                           goat fucker's only .com.
#
#                                         image_caption  \
# 0   It is an image of a small dog and a stuffed an...
# 1   It is an image of two women and two children p...
# 2   The face is of a woman standing in a crowd and...
# 3   An image of a man holding a rainbow flag at a ...
# 4   It is an image of Adolf Hitler dressed in offi...
# 5   It is an image of a black man sitting in front...
# 6   The image shows a woman putting on makeup.  Sh...
# 7            It is an image of a Muslim man in a car.
# 8   It is an image of a smiling Jewish man with lo...
# 9   It is an image of a Caucasian man sitting on s...
# 10  It is an image of a woman in a dress with an u...
# 11  It is an image of a few people around a burnin...
# 13  It is an image of 2012 Republican presidential...
# 14  It is an image of a worried many listening on ...
# 15  It is an image of a person dressed up in a Mar...
# 16         There is a black man smiling in the image.
# 17  The image shows a black woman in a grey dress ...
# 18          The text shows two creatures wrestling. .
# 19  It is an image of Malala Yousafzai smiling, a ...
# 20  It is an image of a woman, likely a mother, ta...
#
#                                       surface_message  \
# 0   It is an image of a small dog and a stuffed an...
# 1   It is an image of two women and two children p...
# 2   The face is of a woman standing in a crowd and...
# 3   An image of a man holding a rainbow flag at a ...
# 4   It is an image of Adolf Hitler dressed in offi...
# 5   It is an image of a black man sitting in front...
# 6   The image shows a woman putting on makeup.  Sh...
# 7   It is an image of a Muslim man in a car. The p...
# 8   It is an image of a smiling Jewish man with lo...
# 9   It is an image of a Caucasian man sitting on s...
# 10  It is an image of a woman in a dress with an u...
# 11  It is an image of a few people around a burnin...
# 13  It is an image of 2012 Republican presidential...
# 14  It is an image of a worried many listening on ...
# 15  It is an image of a person dressed up in a Mar...
# 16  There is a black man smiling in the image. The...
# 17  The image shows a black woman in a grey dress ...
# 18  The text shows two creatures wrestling. . The ...
# 19  It is an image of Malala Yousafzai smiling, a ...
# 20  It is an image of a woman, likely a mother, ta...
#
#                                  background_knowledge  \
# 0   This requires an understanding that black peop...
# 1   Food stamps and tax back programs enroll many ...
# 2   Pussy is often used to reference a female repr...
# 3   The rainbow flag is associated with LGBTQ people.
# 4   Adolf Hitler was the leader of Germany under t...
# 5   1. Understanding dehumanizing racial stereotyp...
# 6   Down syndrome is a genetic disorder caused by ...
# 7      There is a stereotype that Muslims fuck goats.
# 8   Jews are stereotyped as being dishonest and ov...
# 9        1. Knowledge of what cracker means in slang.
# 10  This requires an understanding of the context ...
# 11  There is a debate surrounding the welcoming of...
# 13  Transgender people are people who are physical...
# 14  Minorities are often stereotyped as being crim...
# 15  some people may consider a person of power may...
# 16  1. A master's degree is a higher education qua...
# 17  1. Understanding of racial stereotypes involvi...
# 18  In some parts of East Asia, eating cats and do...
# 19  Malala Yousafzai is an advocate for education ...
# 20            "Goat fucker" is an Islamophobic slur.
#
#                                                     A  \
# 0             The meme is making fun of black people.
# 1   The author is making a negative assumption abo...
# 2             The woman is flirting or being playful.
# 3   The author is suggesting that pride is a negat...
# 4   Hitler is evil although he may look innocent. ...
# 5                      Black people are like monkeys.
# 6   People with Down syndrome can be excited and r...
# 7   The author is perpetuating a negative stereoty...
# 8   The author is suggesting that the Jewish man i...
# 9   The man in the image is trying to fit in with ...
# 10  Ex-girlfriends will sometimes feel they are th...
# 11       Refugees are violent and destructive people.
# 13  Mitt Romney is a transgender person who identi...
# 14                          Minorities are criminals.
# 15  sometimes people cannot control who get in pos...
# 16  The meme is making fun of the idea that having...
# 17  The meme is perpetuating a racial stereotype t...
# 18  The meme is making fun of the cultural differe...
# 19  Malala's courageous behavior during the attemp...
# 20                The meme is promoting Islamophobia.
#
#                                                     B  \
# 0   The author is comparing the dog to a black per...
# 1   People who receive food stamps and tax backs a...
# 2     Women are sexually aroused by being in a crowd.
# 3        Homosexuality is something to be ashamed of.
# 4   The author is saying that Hitler's smile is de...
# 5   The author is making a racist joke by implying...
# 6   The woman with Down syndrome is excited for th...
# 7                           Muslim people fuck goats.
# 8   Jews are dishonest and overly-ambitious in fin...
# 9                       The white man is called poor.
# 10  The author is saying that the woman in the ima...
# 11        Refugees are violent and cause destruction.
# 13  Mitt Romney is a Democrat who identifies as a ...
# 14  Siri is leading the man to jail because he is ...
# 15  The author believes that Americans are stupid ...
# 16  The meme is suggesting that having a master's ...
# 17  Black people are naturally musical and love to...
# 18                       Chinese people are barbaric.
# 19  The meme is suggesting that people who disagre...
# 20                         Muslims are goat fuckers.
#
#                                                     C  \
# 0         The dog is being adopted by a black family.
# 1   The meme is criticizing the government's welfa...
# 2   The woman is enjoying something inappropriate ...
# 3   The author is expressing disdain for the LGBTQ...
# 4   Even the most evil people can appear to be goo...
# 5   African Americans are closer to monkeys than p...
# 6   People with Down syndrome can be excited and r...
# 7   The meme is perpetuating a harmful stereotype ...
# 8                            Jews are greedy thieves.
# 9   It is okay to use racial slurs and stereotypes...
# 10  The meme is making fun of a woman who is upset...
# 11                Refugees are dangerous and violent.
# 13  Mitt Romney is a Republican who acts like a De...
# 14                       Black people belong in jail.
# 15  The person in the meme is suggesting that Amer...
# 16  The meme is trying to portray an offensive ima...
# 17  The meme is stating a racial stereotype that b...
# 18  The meme is making a joke about the cultural d...
# 19  The author is suggesting that Malala Yousafzai...
# 20  The meme is promoting hate speech and Islamoph...
#
#                                                     D answer expert_label  \
# 0                             Black people are apes.       D            H
# 1   Government relief programs make people lazy an...      D            H
# 2            It feels good when your pussy gets hard.      D            H
# 3   The meme is mocking LGBTQ people and their pride.      B            H
# 4                   A smile can hide evil intentions.      A            N
# 5       The meme is perpetuating a racial stereotype.      C            H
# 6   The meme is making fun of people with down syn...      D            H
# 7                                 Muslims fuck goats.      B            H
# 8   The Jewish man is taking advantage of the situ...      C            H
# 9   The author is suggesting that the man in the i...      B            H
# 10  The ex-partner is trying to belittle the perso...      A            H
# 11  Refugees are dangerous and we should not let t...      D            H
# 13  The meme is suggesting that Mitt Romney is sec...      B            H
# 14  The person in the meme is suggesting that the ...      C            H
# 15  The meme is criticizing the American electoral...      A            N
# 16  There is wordplay making fun of black people f...      D            H
# 17  Black people are naturally musical and enjoy d...      C            N
# 18  The author is making a joke about the cultural...      B            H
# 19  The meme is making fun of Malala Yousafzai's a...      A            N
# 20  The author is using a derogatory term to insul...      B            N
#
#                                                prompt  \
# 0   You are given a first-hand account of informat...
# 1   You are given a first-hand account of informat...
# 2   You are given a first-hand account of informat...
# 3   You are given a first-hand account of informat...
# 4   You are given a first-hand account of informat...
# 5   You are given a first-hand account of informat...
# 6   You are given a first-hand account of informat...
# 7   You are given a first-hand account of informat...
# 8   You are given a first-hand account of informat...
# 9   You are given a first-hand account of informat...
# 10  You are given a first-hand account of informat...
# 11  You are given a first-hand account of informat...
# 13  You are given a first-hand account of informat...
# 14  You are given a first-hand account of informat...
# 15  You are given a first-hand account of informat...
# 16  You are given a first-hand account of informat...
# 17  You are given a first-hand account of informat...
# 18  You are given a first-hand account of informat...
# 19  You are given a first-hand account of informat...
# 20  You are given a first-hand account of informat...
#
#                                           result_text predicted_answer  \
# 0   The meme in question describes a situation whe...                N
# 1   The meme in question describes an image of two...                N
# 2   This meme contains sexually explicit language ...                N
# 3   The meme I was given does not appear to be hat...                N
# 4   Based on the given information, the meme can b...                H
# 5   The information provided about the meme does n...                N
# 6   The meme in question consists of a text and an...                N
# 7   The meme given contains two components: text a...                N
# 8   The information given about the meme includes ...                N
# 9   The given meme appears to involve a Caucasian ...                N
# 10  The given meme does not appear to be hateful b...                N
# 11  Based on the information provided, the meme do...                N
# 13  The given meme states, "transrepublican identi...                N
# 14  The information provided about the meme does n...                N
# 15  The given meme includes a text that says "stup...                H
# 16  Based on the given information, the meme does ...                N
# 17  This meme contains a text that states "blacks ...                H
# 18  The meme contains a text that says, "yo dawg i...                N
# 19  The given information includes a meme consisti...                H
# 20  The information provided about the meme includ...                H
#
#                                           prompt_eval  \
# 0   You are given a first-hand account of informat...
# 1   You are given a first-hand account of informat...
# 2   You are given a first-hand account of informat...
# 3   You are given a first-hand account of informat...
# 4   You are given a first-hand account of informat...
# 5   You are given a first-hand account of informat...
# 6   You are given a first-hand account of informat...
# 7   You are given a first-hand account of informat...
# 8   You are given a first-hand account of informat...
# 9   You are given a first-hand account of informat...
# 10  You are given a first-hand account of informat...
# 11  You are given a first-hand account of informat...
# 13  You are given a first-hand account of informat...
# 14  You are given a first-hand account of informat...
# 15  You are given a first-hand account of informat...
# 16  You are given a first-hand account of informat...
# 17  You are given a first-hand account of informat...
# 18  You are given a first-hand account of informat...
# 19  You are given a first-hand account of informat...
# 20  You are given a first-hand account of informat...
#
#                                      result_text_eval predicted_answer_eval
# 0   This meme contains a dog and a stuffed animal ...                     H
# 1   The given meme states "six kids, no husband, n...                     N
# 2   This meme contains sexually explicit and vulga...                     N
# 3   This meme does not appear to be hateful. The t...                     N
# 4   This meme can be considered hateful due to the...                     H
# 5   The information provided about the meme raises...                     H
# 6   This meme does not appear to be hateful based ...                     N
# 7   This meme contains offensive content, specific...                     H
# 8   The given meme contains an image of a smiling ...                     H
# 9   The meme in question depicts a Caucasian man w...                     N
# 10  The information provided does not indicate any...                     N
# 11  Based on the given information about the meme,...                     N
# 13  The given meme does not appear to be hateful. ...                     N
# 14  This meme does not appear to be hateful. The s...                     N
# 15  Based on the given information about the meme,...                     H
# 16  These are my reasons why the meme I'm given is...                     N
# 17  The meme in question states, "blacks are music...                     H
# 18  The given meme contains the text "yo dawg i he...                     N
# 19  Based on the information provided, the meme do...                     H
# 20  This meme contains the text "goat fucker's onl...                     H

# %%
# 0.8125 at 160
(len(nona) - len(nona[nona['predicted_answer_eval'] != nona['expert_label']]))/ len(nona)
# Out:
# 0.2

# %%
cur_iter = 0

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['prompt_eval'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
# This is the information you are given about the meme:
#
# ```
# {'Text': 'behind this smile is an evil man known as hitler.', 'Image Caption': 'It is an image of Adolf Hitler dressed in official attire, including a German military hat. It is a side-profile and he is smiling.', 'Surface Message': 'It is an image of Adolf Hitler dressed in official attire, including a German military hat. It is a side-profile and he is smiling. The author describes the image as behind this smile is an evil man known as hitler.', 'Background Knowledge': 'Adolf Hitler was the leader of Germany under the Nazi party during World War 2. Hitler committed genocide against the Jewish people. People generally consider this evil. A smile is generally associated with being a good person rather than evil.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# The meme in question describes a situation where a dog is depicted as being the only one left at a dog shelter and a black family wanting to adopt it. The image accompanying the description shows a small dog being hugged by a stuffed animal orangutan.
#
# Based on the information provided, it does not appear that the meme is a direct or indirect attack on any particular group of people based on characteristics such as ethnicity, race, nationality, etc. The meme seems to be making a lighthearted observation about being the last dog at a shelter and the feeling of being chosen for adoption. The mention of a black family in the description does not inherently imply any negative or offensive intent. It is simply describing a specific scenario.
#
# Furthermore, there is no violent or dehumanizing speech, statements of inferiority, calls for exclusion or segregation, or mocking of hate crimes in the meme. It seems to be a playful and harmless depiction.
#
# ###
# N

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[0]['predicted_answer'])
# Out:
# N

# %% [markdown]
# ## Hard Cases

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['prompt'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
# This is the information you are given about the meme:
#
# ```
# {'Text': 'six kids, no husband, no job, and food stamps $10,000 back in income taxes.', 'Image Caption': 'It is an image of two women and two children playing with a ball in a driveway. .', 'Surface Message': 'It is an image of two women and two children playing with a ball in a driveway. . The author describes the image as six kids, no husband, no job, and food stamps $10,000 back in income taxes.', 'Background Knowledge': 'Food stamps and tax back programs enroll many Americans today.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# The given meme states, "six kids, no husband, no job, and food stamps $10,000 back in income taxes." The image caption describes it as an image of two women and two children playing with a ball in a driveway.
#
# Analyzing the meme, we can see that it discusses a particular situation where someone has six children, no husband, no job, and receives $10,000 back in income taxes while also receiving food stamps. Although the meme may be making a judgment about the individual in the image, it does not attack anyone based on characteristics such as ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, disability, or disease. It does not contain any violent or dehumanizing speech, statements of inferiority, or calls for exclusion or segregation. The background knowledge provided states that food stamps and tax refund programs are utilized by many Americans, which helps to contextualize the information provided.
#
# Based on this analysis, it can be concluded that the meme is not hateful.
#
# ###
#
# N

# %% [markdown]
# ## Wrong training data

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['prompt'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
# This is the information you are given about the meme:
#
# ```
# {'Text': 'the face you make when your pussy gets hard.', 'Image Caption': 'The face is of a woman standing in a crowd and winking.', 'Surface Message': 'The face is of a woman standing in a crowd and winking. The author describes the image as the face you make when your pussy gets hard.', 'Background Knowledge': 'Pussy is often used to reference a female reproductive organ.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# This meme appears to contain explicit sexual content and uses inappropriate language. However, upon careful analysis, it does not meet the criteria for being considered hateful. While the text uses a vulgar slang term to describe the facial expression, it is not targeting any specific group of people based on their characteristics or attacking them in any way. The meme is crude and offensive, but it does not direct any form of hate towards individuals or communities. Therefore, based on the given information, I would categorize this meme as not hateful.
# ###
# N
