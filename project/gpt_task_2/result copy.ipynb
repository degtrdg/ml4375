# %%
import pandas as pd

checkpoint_file = 'checkpoints/data140.csv'
checkpoint_df = pd.read_csv(checkpoint_file)

# %%
nona = checkpoint_df.dropna()
nona[nona['expert_label'] != nona['predicted_answer']]
# Out:
#      Unnamed: 0                                               text  \
# 6             6  throws people into gas chambers evil throws pe...
# 14           14  six kids, no husband, no job, and food stamps ...
# 23           23  "no, this is no good. you could fit a mexican ...
# 35           35  if this is what they call pride.. then i don't...
# 40           40          with black power comes no responsibility.
# 44           44  what do you get when you cross a pedophile and...
# 52           52  why doesnt mexico have a good athletics team b...
# 59           59                           party tonight? i'm down.
# 80           80  when you are hanging out with your black frien...
# 87           87  when your ex says "you won't find a b*tch half...
# 95           95  your purchase of $19.99 comes to $21.36 after ...
# 96           96  transrepublican identifies as a republican, bu...
# 100         100  so obama imports 70,000 somali immigrants and ...
# 106         106          who said i'm uneducated i have my master.
# 122         122   blacks are musical they always love a good beat.
# 130         130   this would be racist if black people could read.
# 131         131                           good morning sleepyhead.
# 132         132                                      '' shoot them
# 137         137                           goat fucker's only .com.
# 140         140  he told me he was a democrat i asked if i coul...
#
#                                          image_caption  \
# 6    It is an image depicting two portraits of peop...
# 14   It is an image of two women and two children p...
# 23   It is an image of 5 people sitting on top of a...
# 35   An image of a man holding a rainbow flag at a ...
# 40   It is an image of a black man in a suiting sit...
# 44   It is an image of Jack Sparrow from Pirates of...
# 52   An image of Donald Trump in a suit giving a sp...
# 59   The image shows a woman putting on makeup.  Sh...
# 80   It is an image of a Caucasian man sitting on s...
# 87   It is an image of a woman in a dress with an u...
# 95   In the image, one man is holding up a credit c...
# 96   It is an image of 2012 Republican presidential...
# 100  It is an image of Ilhan Omar, who is Muslim, s...
# 106         There is a black man smiling in the image.
# 122  The image shows a black woman in a grey dress ...
# 130  It is an image of a woman reading to 2 babies....
# 131  The picture shows a laughing Bill Cosby in sui...
# 132  It is an image of Malala Yousafzai smiling, a ...
# 137  It is an image of a woman, likely a mother, ta...
# 140  It is an image of 2 white women laughing and s...
#
#                                        surface_message  \
# 6    It is an image depicting two portraits of peop...
# 14   It is an image of two women and two children p...
# 23   It is an image of 5 people sitting on top of a...
# 35   An image of a man holding a rainbow flag at a ...
# 40   It is an image of a black man in a suiting sit...
# 44   It is an image of Jack Sparrow from Pirates of...
# 52   An image of Donald Trump in a suit giving a sp...
# 59   The image shows a woman putting on makeup.  Sh...
# 80   It is an image of a Caucasian man sitting on s...
# 87   It is an image of a woman in a dress with an u...
# 95   In the image, one man is holding up a credit c...
# 96   It is an image of 2012 Republican presidential...
# 100  It is an image of Ilhan Omar, who is Muslim, s...
# 106  There is a black man smiling in the image. The...
# 122  The image shows a black woman in a grey dress ...
# 130  It is an image of a woman reading to 2 babies....
# 131  The picture shows a laughing Bill Cosby in sui...
# 132  It is an image of Malala Yousafzai smiling, a ...
# 137  It is an image of a woman, likely a mother, ta...
# 140  It is an image of 2 white women laughing and s...
#
#                                   background_knowledge  \
# 6    In World War II, Adolf Hitler, the leader of G...
# 14   Food stamps and tax back programs enroll many ...
# 106  The meme is trying to portray an offensive ima...
# 122  The meme is stating a racial stereotype that b...
# 130  The author is making a racist joke about Black...
# 131  Bill Cosby's sexual assaults was nothing more ...
# 132  The author is suggesting that Malala Yousafzai...
# 137  The meme is promoting hate speech and Islamoph...
# 140  The author is implying that Democrats are more...
#
#                                                      D answer expert_label  \
# 6                          Jesus is as evil as Hitler.      C            H
# 14   Government relief programs make people lazy an...      D            H
# 23   The wall depicted is not good enough to preven...      D            N
# 35   The meme is mocking LGBTQ people and their pride.      B            H
# 40   The meme is making fun of the Black Power move...      A            H
# 44   The author is making a joke about R Kelly bein...      C            N
# 52   The meme is making fun of Donald Trump's polic...      C            H
# 59   The meme is making fun of people with down syn...      D            H
# 80   The author is suggesting that the man in the i...      B            H
# 87   The ex-partner is trying to belittle the perso...      A            H
# 95                                  Taxation is theft.      C            H
# 96   The meme is suggesting that Mitt Romney is sec...      B            H
# 100  Ilhan Omar and Obama are leading a conspiracy ...      D            H
# 106  There is wordplay making fun of black people f...      D            H
# 122  Black people are naturally musical and enjoy d...      C            N
# 130  This meme is perpetuating a racist stereotype ...      B            H
# 131  The meme is making light of a serious issue, s...      C            N
# 132  The meme is making fun of Malala Yousafzai's a...      A            N
# 137  The author is using a derogatory term to insul...      B            N
# 140                            Democrat men are women.      D            N
#
#                                                 prompt  \
# 6    You are given a first-hand account of informat...
# 14   You are given a first-hand account of informat...
# 23   You are given a first-hand account of informat...
# 35   You are given a first-hand account of informat...
# 40   You are given a first-hand account of informat...
# 44   You are given a first-hand account of informat...
# 52   You are given a first-hand account of informat...
# 59   You are given a first-hand account of informat...
# 80   You are given a first-hand account of informat...
# 87   You are given a first-hand account of informat...
# 95   You are given a first-hand account of informat...
# 96   You are given a first-hand account of informat...
# 100  You are given a first-hand account of informat...
# 106  You are given a first-hand account of informat...
# 122  You are given a first-hand account of informat...
# 130  You are given a first-hand account of informat...
# 131  You are given a first-hand account of informat...
# 132  You are given a first-hand account of informat...
# 137  You are given a first-hand account of informat...
# 140  You are given a first-hand account of informat...
#
#                                            result_text predicted_answer
# 6    This meme compares Adolf Hitler and Jesus, pre...                N
# 14   This meme does not appear to be hateful. The t...                N
# 23   Based on the provided information, the meme ca...                H
# 35   The meme in question includes an image of a ma...                N
# 40   The given meme statement "with black power com...                N
# 44   Based on the information provided, I would cla...                H
# 52   This meme contains a joke about the relative l...                N
# 59   This meme does not appear to be hateful. Here'...                N
# 80   This meme does not appear to be hateful. The i...                N
# 87   This meme does not appear to be hateful based ...                N
# 95   Based on the provided information, it is possi...                N
# 96   This meme does not appear to be hateful. It is...                N
# 100  The meme describes how Obama imported 70,000 S...                N
# 106  The meme in question states, "who said I'm une...                N
# 122  Based on the information provided, the meme ca...                H
# 130  This meme contains a photo of a woman reading ...                N
# 131  The meme in question shows a picture of Bill C...                H
# 132  The meme seems to show an image of Malala Yous...                H
# 137  The meme states "goat fucker's only .com" alon...                H
# 140  This meme appears to make a joke based on the ...                H

# %%
# 0.8125 at 160
# 0.8236 at 160
(len(nona) - len(nona[nona['expert_label'] != nona['predicted_answer']]))/ len(nona)
# Out:
# 0.84375

# %%
cur_iter = 10

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['prompt'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
#
# This is background information that might be relevant for understanding the meme:
# Many right-wing economists believe that taxation is theft because it is forced on the people. / Sales tax is usually around 7%, which is close to the price increase in the meme.
#
#
# This is the information you are given about the meme:
#
#
# ```
# {'Text': 'your purchase of $19.99 comes to $21.36 after theft.', 'Image Caption': 'In the image, one man is holding up a credit card in a swiping motion. An African American man is speaking, and holding up a credit card scanner. .', 'Surface Message': 'In the image, one man is holding up a credit card in a swiping motion. An African American man is speaking, and holding up a credit card scanner. . The author describes the image as your purchase of $19.99 comes to $21.36 after theft.', 'Background Knowledge': 'Many right-wing economists believe that taxation is theft because it is forced on the people. / Sales tax is usually around 7%, which is close to the price increase in the meme.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# Based on the provided information, it is possible to reason whether the meme is hateful or not.
#
# The text accompanying the meme states, "your purchase of $19.99 comes to $21.36 after theft." This text seems to imply that the additional $1.37 represents theft or an increase in price due to theft.
#
# The image description notes that one man is holding up a credit card in a swiping motion, while an African American man is speaking and holding up a credit card scanner.
#
# Analyzing these elements, there is no direct or indirect attack on any individual or group based on ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, disability, or disease. The image and text do not use violent or dehumanizing language, nor do they compare the individuals involved to non-human objects.
#
# Furthermore, the meme seems to be making a play on words related to taxation being considered "theft" by some right-wing economists. The price increase shown in the meme is similar to sales taxes, which are usually present in many retail transactions.
#
# Based on this information, the meme does not appear to meet the criteria of being hateful. It does not target or attack any specific group or individual based on their characteristics.
#
# ###
# N

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[0]['predicted_answer'])
# Out:
# N

# %% [markdown]
# ## Hard Cases

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['prompt'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
# This is the information you are given about the meme:
#
# ```
# {'Text': 'six kids, no husband, no job, and food stamps $10,000 back in income taxes.', 'Image Caption': 'It is an image of two women and two children playing with a ball in a driveway. .', 'Surface Message': 'It is an image of two women and two children playing with a ball in a driveway. . The author describes the image as six kids, no husband, no job, and food stamps $10,000 back in income taxes.', 'Background Knowledge': 'Food stamps and tax back programs enroll many Americans today.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# The given meme states, "six kids, no husband, no job, and food stamps $10,000 back in income taxes." The image caption describes it as an image of two women and two children playing with a ball in a driveway.
#
# Analyzing the meme, we can see that it discusses a particular situation where someone has six children, no husband, no job, and receives $10,000 back in income taxes while also receiving food stamps. Although the meme may be making a judgment about the individual in the image, it does not attack anyone based on characteristics such as ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, disability, or disease. It does not contain any violent or dehumanizing speech, statements of inferiority, or calls for exclusion or segregation. The background knowledge provided states that food stamps and tax refund programs are utilized by many Americans, which helps to contextualize the information provided.
#
# Based on this analysis, it can be concluded that the meme is not hateful.
#
# ###
#
# N

# %% [markdown]
# ## Wrong training data

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['prompt'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
# This is the information you are given about the meme:
#
# ```
# {'Text': 'the face you make when your pussy gets hard.', 'Image Caption': 'The face is of a woman standing in a crowd and winking.', 'Surface Message': 'The face is of a woman standing in a crowd and winking. The author describes the image as the face you make when your pussy gets hard.', 'Background Knowledge': 'Pussy is often used to reference a female reproductive organ.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# This meme appears to contain explicit sexual content and uses inappropriate language. However, upon careful analysis, it does not meet the criteria for being considered hateful. While the text uses a vulgar slang term to describe the facial expression, it is not targeting any specific group of people based on their characteristics or attacking them in any way. The meme is crude and offensive, but it does not direct any form of hate towards individuals or communities. Therefore, based on the given information, I would categorize this meme as not hateful.
# ###
# N
