# %%
import pandas as pd

checkpoint_file = 'checkpoints_eval/data62.csv'
checkpoint_df = pd.read_csv(checkpoint_file)

# %%
nona = checkpoint_df.dropna()
nona[nona['predicted_answer_eval'] != nona['expert_label']]
# Out:
#     Unnamed: 0.1  index  Unnamed: 0  \
# 0              0      6           6
# 2              2     23          23
# 3              3     32          32
# 9              9     61          61
# 12            12     80          80
# 13            13     87          87
# 15            15     95          95
# 16            16     96          96
# 17            17     99          99
# 19            19    106         106
# 24            24    151         151
# 25            25    152         152
# 32            32    190         190
# 33            33    192         192
# 34            34    193         193
# 36            36    203         203
# 37            37    208         208
# 41            41    234         234
# 43            43    245         245
# 50            50    264         264
# 51            51    275         275
# 52            52    279         279
# 53            53    282         282
# 54            54    293         293
# 55            55    297         297
# 56            56    308         308
# 61            61    332         332
#
#                                                  text  \
# 0   throws people into gas chambers evil throws pe...
# 2   "no, this is no good. you could fit a mexican ...
# 3        the face you make when your pussy gets hard.
# 9   if they aren't meant to cook why do they have ...
# 12  when you are hanging out with your black frien...
# 13  when your ex says "you won't find a b*tch half...
# 15  your purchase of $19.99 comes to $21.36 after ...
# 16  transrepublican identifies as a republican, bu...
# 17          siri take me home starting route to jail.
# 19          who said i'm uneducated i have my master.
# 24  dark humour is like a child with cancer it doe...
# 25            very tired after group sex mohammed is.
# 32  there's a reason they have children. they are ...
# 33  yesterday i told my wife her soup tasted like ...
# 34  gay friends asked for directions told him to g...
# 36       how long can i run? till the chain tightens.
# 37     survives ebola gets adopted by angelina jolie.
# 41                had secret door before it was cool.
# 43  white people throwing rice at weddings. "why a...
# 50  i support terrorists because they're pea brain...
# 51  the same enemy. we all have by the same people...
# 52  is bribing muslims for liberal votes justin tr...
# 53        uncle daddy and me gonna have us a nephson.
# 54   i said glass of orange not glass of apple juice.
# 55  women can wear what they want you dont have th...
# 56  i bought stevie wonder a cheese grater for chr...
# 61  the hardest part of breaking up with a japanes...
#
#                                         image_caption  \
# 0   It is an image depicting two portraits of peop...
# 2   It is an image of 5 people sitting on top of a...
# 3   The face is of a woman standing in a crowd and...
# 9   It is an image of scrambled eggs on a plate wi...
# 12  It is an image of a Caucasian man sitting on s...
# 13  It is an image of a woman in a dress with an u...
# 15  In the image, one man is holding up a credit c...
# 16  It is an image of 2012 Republican presidential...
# 17  It is an image of a worried many listening on ...
# 19         There is a black man smiling in the image.
# 24  A white man wearing a suit is standing in fron...
# 25  It is an image of an Asian man laying on a cou...
# 32  A small white mouse is looking at the camera. ...
# 33  The image shows a man in a suit with a bruised...
# 34  It is an image of a group of people and embers...
# 36  It is an image of an African American man smil...
# 37  The first image is of two skinny african child...
# 41    It is an image of Anne Frank writing in a book.
# 43  It is an image of 2 people sitting on a bench ...
# 50  The image shows Osama bin Laden wearing a whit...
# 51  There are 3 images of a black man, native woma...
# 52  It is an image of Barrack Obama and Justin Tru...
# 53  It is an image of a man and a women standing i...
# 54  The image shows Adolf Hitler standing with his...
# 55  It is an image of 2 parts. The top part shows ...
# 56                   It is an image of Stevie Wonder.
# 61  It is an image of a young east Asian woman loo...
#
#                                       surface_message  \
# 0   It is an image depicting two portraits of peop...
# 2   It is an image of 5 people sitting on top of a...
# 3   The face is of a woman standing in a crowd and...
# 9   It is an image of scrambled eggs on a plate wi...
# 12  It is an image of a Caucasian man sitting on s...
# 13  It is an image of a woman in a dress with an u...
# 15  In the image, one man is holding up a credit c...
# 16  It is an image of 2012 Republican presidential...
# 17  It is an image of a worried many listening on ...
# 19  There is a black man smiling in the image. The...
# 24  A white man wearing a suit is standing in fron...
# 25  It is an image of an Asian man laying on a cou...
# 32  A small white mouse is looking at the camera. ...
# 33  The image shows a man in a suit with a bruised...
# 34  It is an image of a group of people and embers...
# 36  It is an image of an African American man smil...
# 37  The first image is of two skinny african child...
# 41  It is an image of Anne Frank writing in a book...
# 43  It is an image of 2 people sitting on a bench ...
# 50  The image shows Osama bin Laden wearing a whit...
# 51  The first image's caption is by the author, an...
# 52  It is an image of Barrack Obama and Justin Tru...
# 53  It is an image of a man and a women standing i...
# 54  The image shows Adolf Hitler standing with his...
# 55  It is an image of 2 parts. The top part shows ...
# 56  It is an image of Stevie Wonder. The author de...
# 61  It is an image of an Asian woman looking towar...
#
#                                  background_knowledge  \
# 0   In World War II, Adolf Hitler, the leader of G...
# 2   Knowledge of the debate surrounding immigratio...
# 3   Pussy is often used to reference a female repr...
# 9   Scrambled eggs are made with eggs and milk. Wo...
# 12       1. Knowledge of what cracker means in slang.
# 13  This requires an understanding of the context ...
# 15  Many right-wing economists believe that taxati...
# 16  Transgender people are people who are physical...
# 17  Minorities are often stereotyped as being crim...
# 19  1. A master's degree is a higher education qua...
# 24  This requires knowing cancer kills children an...
# 25         Mohammad is the prophet who founded Islam.
# 32  This requires an understanding of the term "pe...
# 33  The bruises indicate an altercation between th...
# 34  Gay people have been discriminated and physica...
# 36  Chains are usually used to prevent prisoners f...
# 37   Knowledge of Angelina Jolie's adoption of chi...
# 41  Anne Frank is a girl who is well-known for her...
# 43  1. Understanding of cultural practices and tra...
# 50  Osama bin Laden was a Muslim extremist and ter...
# 51  This requires an awareness of historical explo...
# 52  Sharia law is considered an extremist type of ...
# 53  A "nephson" is the son of a man who marries hi...
# 54  Juice is a word that sounds very similar to "J...
# 55  Some western countries have restricted Muslim ...
# 56  Stevie Wonder is blind. Blind people read brai...
# 61  America dropped two atomic bombs on Japan at t...
#
#                                                     A  \
# 0   The author is comparing Hitler and Jesus, sugg...
# 2   The current border wall is not effective in pr...
# 3             The woman is flirting or being playful.
# 9   Women are meant to cook and take care of house...
# 12  The man in the image is trying to fit in with ...
# 13  Ex-girlfriends will sometimes feel they are th...
# 15  The meme is making fun of African Americans by...
# 16  Mitt Romney is a transgender person who identi...
# 17                          Minorities are criminals.
# 19  The meme is making fun of the idea that having...
# 24  Dark humor is always funny, even when it's abo...
# 25                            Mohammad had group sex.
# 32  The meme is suggesting that people who have ch...
# 33  The man learned to appreciate his wife's cooki...
# 34                     Gay people should be straight.
# 36  The meme is suggesting that the African Americ...
# 37  Angelina Jolie only adopts children who surviv...
# 41     Anne Frank was cool for hiding from the Nazis.
# 43  The author is criticizing the Western traditio...
# 50  Terrorists are unintelligent, just like bin La...
# 51  Oppressed people should stand against oppressi...
# 52  The author believes that Justin Trudeau is try...
# 53                                   Incest is funny.
# 54  The meme is making fun of Hitler's actions aga...
# 55  The meme is arguing that women should have the...
# 56  Stevie Wonder is not able to read a book with ...
# 61  Breaking up with a Japanese girlfriend is diff...
#
#                                                     B  \
# 0   The meme is trying to make a point about the s...
# 2   The author is making a sarcastic comment about...
# 3     Women are sexually aroused by being in a crowd.
# 9   Women are meant to cook because they have eggs...
# 12                      The white man is called poor.
# 13  The author is saying that the woman in the ima...
# 15  The author is suggesting that taxation is a fo...
# 16  Mitt Romney is a Democrat who identifies as a ...
# 17  Siri is leading the man to jail because he is ...
# 19  The meme is suggesting that having a master's ...
# 24  Dark humor is funny because it is offensive an...
# 25  The meme is making fun of the prophet Mohammad...
# 32                              Mice are pedophiles.
# 33  The author is suggesting that the man's wife b...
# 34  The meme is suggesting that gay people should ...
# 36                   African Americans are prisoners.
# 37  Angelina Jolie adopts children who survive dif...
# 41  Anne Frank was the first to have a secret door...
# 43  The meme is highlighting the cultural differen...
# 50  The author is joking about supporting terroris...
# 51  The meme is about unity and resistance against...
# 52  Justin Trudeau wants to bring Sharia law to Ca...
# 53  It is making fun of people who marry their fam...
# 54  The meme is making fun of Jews and their relat...
# 55  Women should have the right to choose what the...
# 56  Stevie Wonder is not capable of understanding ...
# 61  Breaking up with an Asian woman is like droppi...
#
#                                                     C  \
# 0   The author is highlighting the hipocracy of th...
# 2   The meme is making fun of the immigration deba...
# 3   The woman is enjoying something inappropriate ...
# 9             Women are meant to cook for the family.
# 12  It is okay to use racial slurs and stereotypes...
# 13  The meme is making fun of a woman who is upset...
# 15  Taxation, which is government seizure of prope...
# 16  Mitt Romney is a Republican who acts like a De...
# 17                       Black people belong in jail.
# 19  The meme is trying to portray an offensive ima...
# 24               Children with cancer don't get old.
# 25  The author is making fun of Mohammad's sexual ...
# 32  The meme is making a joke about the idea that ...
# 33       The meme is making fun of domestic violence.
# 34  The meme is making fun of the idea that gay pe...
# 36  Black people are criminals and run from the po...
# 37  Angelina Jolie's adoption made no meaningful i...
# 41  Anne Frank was the original "hipster" who did ...
# 43  White people tend to waste a lot during weddin...
# 50  The meme is making fun of Osama bin Laden and ...
# 51  The meme is advocating for unity and resistanc...
# 52  The meme is suggesting that Justin Trudeau is ...
# 53  The author is suggesting that the man and woma...
# 54  The author is making a joke about Hitler's act...
# 55  Muslims are hypocritical for criticizing hijab...
# 56  Stevie Wonder cut his fingers trying to read t...
# 61  The author is making a joke about the serious ...
#
#                                                     D answer expert_label  \
# 0                         Jesus is as evil as Hitler.      C            H
# 2   The wall depicted is not good enough to preven...      D            N
# 3            It feels good when your pussy gets hard.      D            H
# 9   The author is making a sexist joke about women...      C            N
# 12  The author is suggesting that the man in the i...      B            H
# 13  The ex-partner is trying to belittle the perso...      A            H
# 15                                 Taxation is theft.      C            H
# 16  The meme is suggesting that Mitt Romney is sec...      B            H
# 17  The person in the meme is suggesting that the ...      C            H
# 19  There is wordplay making fun of black people f...      D            H
# 24  Dark humor is always funny, no matter how inap...      C            H
# 25            Mohammad is very tired after group sex.      A            N
# 32  The author is accusing people who have childre...      B            N
# 33                      Wives are physically abusive.      D            H
# 34  The meme is trying to make fun of gay people b...      A            H
# 36  The author is saying that the man is trapped a...      C            H
# 37     Angelina Jolie is a savior for these children.      C            H
# 41                             Anne Frank was trendy.      A            H
# 43  The meme is making fun of the cultural practic...      C            H
# 50  The author is comparing themselves to Osama bi...      A            N
# 51  The meme is trying to convey a message of unit...      A            H
# 52  Justin Trudeau is accused of favoring foreigne...      B            N
# 53  The uncle and his nephew are going to have a c...      B            H
# 54  The author is making a joke about Hitler's act...      B            N
# 55  The author is saying that women should have th...      C            H
# 56                       Stevie Wonder is illiterate.      C            H
# 61  The Japanese people were unwise to let America...      D            H
#
#                                                prompt  \
# 0   You are given a first-hand account of informat...
# 2   You are given a first-hand account of informat...
# 3   You are given a first-hand account of informat...
# 9   You are given a first-hand account of informat...
# 12  You are given a first-hand account of informat...
# 13  You are given a first-hand account of informat...
# 15  You are given a first-hand account of informat...
# 16  You are given a first-hand account of informat...
# 17  You are given a first-hand account of informat...
# 19  You are given a first-hand account of informat...
# 24  You are given a first-hand account of informat...
# 25  You are given a first-hand account of informat...
# 32  You are given a first-hand account of informat...
# 33  You are given a first-hand account of informat...
# 34  You are given a first-hand account of informat...
# 36  You are given a first-hand account of informat...
# 37  You are given a first-hand account of informat...
# 41  You are given a first-hand account of informat...
# 43  You are given a first-hand account of informat...
# 50  You are given a first-hand account of informat...
# 51  You are given a first-hand account of informat...
# 52  You are given a first-hand account of informat...
# 53  You are given a first-hand account of informat...
# 54  You are given a first-hand account of informat...
# 55  You are given a first-hand account of informat...
# 56  You are given a first-hand account of informat...
# 61  You are given a first-hand account of informat...
#
#                                           result_text predicted_answer  \
# 0   Based on the given information, the meme can b...                N
# 2   Based on the given information, the meme does ...                H
# 3   This meme contains a text that describes the i...                N
# 9   The text on the meme implies that women are me...                H
# 12  Based on the given information, it seems that ...                N
# 13  This meme does not appear to be hateful. It po...                N
# 15  Based on the information provided, the meme do...                N
# 16  The meme in question states that Mitt Romney, ...                N
# 17  The meme in question includes the text "siri t...                N
# 19  The meme does not appear to be hateful based o...                N
# 24  The meme in question states, "dark humour is l...                N
# 25  The meme contains a description that refers to...                H
# 32  Upon analyzing the given information, it is cl...                H
# 33  These are my reasons why the meme I'm given is...                N
# 34  This meme does not appear to be hateful. The s...                N
# 36  Based on the provided information, the meme ap...     Undetermined
# 37  The meme uses two images, one showing two skin...                N
# 41  The meme in question states, "had secret door ...                N
# 43  This meme does not appear to be hateful. The t...                N
# 50  This meme can be considered as hateful. The te...                H
# 51  Based on the given information, it seems that ...                N
# 52  This meme contains several elements that sugge...                H
# 53  The information provided does not contain any ...                N
# 54  The meme in question contains an image of Adol...                H
# 55  The meme in question portrays two parts. The t...                N
# 56  This meme is a joke that plays on the double m...                N
# 61  This meme contains a joke that uses the droppi...                N
#
#                                           prompt_eval  \
# 0   You are given a first-hand account of informat...
# 2   You are given a first-hand account of informat...
# 3   You are given a first-hand account of informat...
# 9   You are given a first-hand account of informat...
# 12  You are given a first-hand account of informat...
# 13  You are given a first-hand account of informat...
# 15  You are given a first-hand account of informat...
# 16  You are given a first-hand account of informat...
# 17  You are given a first-hand account of informat...
# 19  You are given a first-hand account of informat...
# 24  You are given a first-hand account of informat...
# 25  You are given a first-hand account of informat...
# 32  You are given a first-hand account of informat...
# 33  You are given a first-hand account of informat...
# 34  You are given a first-hand account of informat...
# 36  You are given a first-hand account of informat...
# 37  You are given a first-hand account of informat...
# 41  You are given a first-hand account of informat...
# 43  You are given a first-hand account of informat...
# 50  You are given a first-hand account of informat...
# 51  You are given a first-hand account of informat...
# 52  You are given a first-hand account of informat...
# 53  You are given a first-hand account of informat...
# 54  You are given a first-hand account of informat...
# 55  You are given a first-hand account of informat...
# 56  You are given a first-hand account of informat...
# 61  You are given a first-hand account of informat...
#
#                                      result_text_eval predicted_answer_eval
# 0   The meme is presenting a critical view of perc...                     N
# 2   The meme in question seems to be making a joke...                     H
# 3   These are my reasons why the meme I'm given is...                     N
# 9   The meme in question appears to draw upon biol...                     H
# 12  Considering the provided information, the term...                     N
# 13  This meme appears to play on the common tropes...                     N
# 15  The meme provided uses the term "theft" in a c...                     N
# 16  The meme appears to be a play on words, using ...                     N
# 17  The meme in question appears to utilize irony ...                     N
# 19  These are my reasons why the meme I'm given is...                     N
# 24  The meme uses an analogy comparing dark humor ...                     N
# 25  The meme in question appears to be disrespectf...                     H
# 32  The meme in question suggests that the reason ...                     H
# 33  These are my reasons why the meme I'm given is...                     N
# 34  The meme described features text that plays on...                     N
# 36  Upon reviewing the content of the meme, I iden...                     N
# 37  The content of the meme leverages a stereotype...                     N
# 41  The given meme refers to Anne Frank, who is kn...                H\n```
# 43  From the information provided and the context ...                     N
# 50  The meme in question seems to ridicule the int...                N\n```
# 51  The meme appears to call attention to a shared...                     N
# 52  The meme in question appears to utilize langua...                     H
# 53  The meme in question appears to be making a li...                     N
# 54  Given the information about the meme and the p...                     H
# 55  The meme's text and accompanying images seem t...                     N
# 56  The information within the meme utilizes the k...                     N
# 61  This particular meme appears to use a historic...                     N

# %%
# 0.8125 at 160
(len(nona) - len(nona[nona['predicted_answer_eval'] != nona['expert_label']]))/ len(nona)
# Out:
# 0.5714285714285714

# %%
cur_iter = 2

# %%
print(nona[nona['expert_label'] != nona['predicted_answer_eval']].iloc[cur_iter]['prompt_eval'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
#
# This is background information that might be relevant for understanding the meme:
# Pussy is often used to reference a female reproductive organ.
#
#
# This is the information you are given about the meme:
#
#
# ```
# {'Text': 'the face you make when your pussy gets hard.', 'Image Caption': 'The face is of a woman standing in a crowd and winking.', 'Surface Message': 'The face is of a woman standing in a crowd and winking. The author describes the image as the face you make when your pussy gets hard.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# Based on the given information, the meme does appear to be hateful.
#
# The text of the meme includes a statement that suggests that the presence of a Mexican child is undesirable or problematic. This implies that Mexican children are something to be excluded or kept out, which aligns with the definition of hate speech that includes calls for exclusion or segregation.
#
# Furthermore, the image itself shows people sitting on top of a wall, which can be seen as mocking the issue of border security between the United States and Mexico. Mocking hate crime is considered hate speech, and this meme can be seen as mocking the situation and potentially trivializing the experiences of those affected by it.
#
# Therefore, considering the dehumanizing statement and the potential mocking of a serious issue, it can be concluded that this meme falls under the category of hate speech.
#
# ###
# H

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[0]['predicted_answer'])
# Out:
# N

# %% [markdown]
# ## Hard Cases

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['prompt'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
# This is the information you are given about the meme:
#
# ```
# {'Text': 'six kids, no husband, no job, and food stamps $10,000 back in income taxes.', 'Image Caption': 'It is an image of two women and two children playing with a ball in a driveway. .', 'Surface Message': 'It is an image of two women and two children playing with a ball in a driveway. . The author describes the image as six kids, no husband, no job, and food stamps $10,000 back in income taxes.', 'Background Knowledge': 'Food stamps and tax back programs enroll many Americans today.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# The given meme states, "six kids, no husband, no job, and food stamps $10,000 back in income taxes." The image caption describes it as an image of two women and two children playing with a ball in a driveway.
#
# Analyzing the meme, we can see that it discusses a particular situation where someone has six children, no husband, no job, and receives $10,000 back in income taxes while also receiving food stamps. Although the meme may be making a judgment about the individual in the image, it does not attack anyone based on characteristics such as ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, disability, or disease. It does not contain any violent or dehumanizing speech, statements of inferiority, or calls for exclusion or segregation. The background knowledge provided states that food stamps and tax refund programs are utilized by many Americans, which helps to contextualize the information provided.
#
# Based on this analysis, it can be concluded that the meme is not hateful.
#
# ###
#
# N

# %% [markdown]
# ## Wrong training data

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['prompt'])
# Out:
# You are given a first-hand account of information from a meme. You are given different pieces of information to figure out whether the meme is hateful (H) or not (N) after reasoning why you chose what you did.
#
# An example output would be like the following. Following this format is VERY important:
#
# ```
# These are my reasons why the meme I'm given isn't hateful.
# ###
# N
# ```
#
# A meme is hateful if it is a  direct or indirect attack on people based on characteristics, including ethnicity, race, nationality, immigration status, religion, caste, sex, gender identity, sexual orientation, and disability or disease. We define attack as violent or dehumanizing (comparing people to non-human things, e.g. animals) speech, statements of inferiority, and calls for exclusion or segregation. Mocking hate crime is also considered hate speech.
# This is the information you are given about the meme:
#
# ```
# {'Text': 'the face you make when your pussy gets hard.', 'Image Caption': 'The face is of a woman standing in a crowd and winking.', 'Surface Message': 'The face is of a woman standing in a crowd and winking. The author describes the image as the face you make when your pussy gets hard.', 'Background Knowledge': 'Pussy is often used to reference a female reproductive organ.'}
# ```
#
# Reason and do critical thinking to verify if it is hateful or not and be careful to see if it fits the definition of hateful. After your reasoning, finish by writing three hashtags (i.e. ###) to separate the reasoning and the answer and ONLY outputting 'H' if the meme is hateful or 'N' if it is not hateful. Following this format is VERY important.

# %%
print(nona[nona['expert_label'] != nona['predicted_answer']].iloc[cur_iter]['result_text'])
# Out:
# This meme appears to contain explicit sexual content and uses inappropriate language. However, upon careful analysis, it does not meet the criteria for being considered hateful. While the text uses a vulgar slang term to describe the facial expression, it is not targeting any specific group of people based on their characteristics or attacking them in any way. The meme is crude and offensive, but it does not direct any form of hate towards individuals or communities. Therefore, based on the given information, I would categorize this meme as not hateful.
# ###
# N
