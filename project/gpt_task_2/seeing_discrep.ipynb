# %%
import pandas as pd
first = pd.read_csv('checkpoints/data340.csv').dropna()
first
# Out:
#      Unnamed: 0                                               text  \
# 0             0                      celebrating the weekend like.
# 1             1  what do you get when you cross harvey price wi...
# 2             2  2 years on the job... 4 million jobs gained 1 ...
# 3             3  and just like that liberals didn't want illega...
# 4             4  when you're the only dog left at the dog shelt...
# ..          ...                                                ...
# 335         335  why can't you play uno with a mexican? because...
# 336         336  3.8 billion of them on earth. why isn't it cle...
# 338         338  barn army enlist, and bomb ant hills "grab you...
# 339         339  when the pope addresses the people he does it ...
# 340         340  now is the winter of our discontent made glori...
#
#                                          image_caption  \
# 0    It is an image of two naked African boys celeb...
# ...

# %%
nona = first.dropna()
nona[nona['predicted_answer'] != nona['expert_label']]
# Out:
#      Unnamed: 0                                               text  \
# 6             6  throws people into gas chambers evil throws pe...
# 14           14  six kids, no husband, no job, and food stamps ...
# 23           23  "no, this is no good. you could fit a mexican ...
# 32           32       the face you make when your pussy gets hard.
# 35           35  if this is what they call pride.. then i don't...
# ..          ...                                                ...
# 320         320             when each letter is a mental disorder.
# 325         325        what the neighbors see what my father sees.
# 326         326  when you forgo history and embrace your slavem...
# 332         332  the hardest part of breaking up with a japanes...
# 334         334  what's "saggin"' spelled backwards? hint: they...
#
#                                          image_caption  \
# 6    It is an image depicting two portraits of peop...
# ...

# %%
nona = first.dropna()
(len(nona) - len(nona[nona['predicted_answer'] != nona['expert_label']]))/ len(nona)
# nona[nona['predicted_answer'] != nona['expert_label']]
# nona
# Out:
# 0.7980769230769231

# %%
second = pd.read_csv('checkpoints_eval/data62.csv').dropna()
second.iloc[0]['result_text']
# Out:
# 'Based on the given information, the meme can be seen as comparing Adolf Hitler, who committed genocide on the Jewish people, to Jesus, a key figure in Christianity. In the top panel, Hitler is depicted as "evil" for throwing people into gas chambers, while in the bottom panel, Jesus is depicted as "good" for throwing people into eternal pits of fire.\n\nWhile the meme uses a comparison between Hitler and Jesus, it does not attack any specific group of people based on their characteristics. It does not make any violent or dehumanizing statements against a particular ethnicity, race, nationality, religion, or any other characteristic. It also does not call for exclusion or segregation. The meme seems to be making a comparison between two historical figures in a provocative way, but it does not meet the criteria of a hateful meme.\n\n###\nN'

# %%
second.iloc[0]
# Out:
# Unnamed: 0.1                                                             0
# index                                                                    6
# Unnamed: 0                                                               6
# text                     throws people into gas chambers evil throws pe...
# image_caption            It is an image depicting two portraits of peop...
# surface_message          It is an image depicting two portraits of peop...
# background_knowledge     In World War II, Adolf Hitler, the leader of G...
# A                        The author is comparing Hitler and Jesus, sugg...
# B                        The meme is trying to make a point about the s...
# C                        The author is highlighting the hipocracy of th...
# D                                              Jesus is as evil as Hitler.
# answer                                                                   C
# ...
